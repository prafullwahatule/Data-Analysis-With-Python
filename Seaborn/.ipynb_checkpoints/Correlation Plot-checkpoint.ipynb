# %% [markdown]
# # Correlation

# %% [markdown]
# ## Scatter Plot
#
# A scatter plot is used to show the relationship between two numerical variables.
# Each point represents one observation in the dataset.

# %% [markdown]
# ### Step 1: Initialize Global Setting

# %%
# Import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# setting up the params
large = 22
med = 12
small = 12

params = {
    'axes.titlesize': large,
    'legend.fontsize': med,
    'figure.figsize': (16, 10),
    'axes.labelsize': med,
    'xtick.labelsize': med,
    'ytick.labelsize': med,
    'figure.titlesize': large
}

# override default parameters of plot
plt.rcParams.update(params)

# set style (updated seaborn style)
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ### Step 2: Import Dataset

# %%
# "C:\Users\Prafull Wahatule\Desktop\Python_DA\Data\midwest.csv"

df = pd.read_csv(r"C:\Users\Prafull Wahatule\Desktop\Python_DA\Data\midwest.csv")
df
# Out:
#       PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0     561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1     562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2     563       BOND    IL  0.022     14991   681.409091     14477       429
# 3     564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4     565      BROWN    IL  0.018      5836   324.222222      5264       547
# ..    ...        ...   ...    ...       ...          ...       ...       ...
# 327  3045   WALWORTH    WI  0.032     75000  2343.750000     72747       454
# 328  3046   WASHBURN    WI  0.050     13772   275.440000     13585        25
# 329  3049    WAUPACA    WI  0.045     46104  1024.533330     45695        22
# 330  3050   WAUSHARA    WI  0.037     19385   523.918919     19094        29
# 331  3052       WOOD    WI  0.048     73605  1533.437500     72157        90
#
# ...

# %% [markdown]
# ### Step 3: Prepare Data

# %%
# Unique Category

categories = np.unique(df['category'])
clen = len(categories)
clen

colours = [plt.cm.tab10(i / float(clen - 1)) for i in range(clen)]
colours
# Out:
# [(np.float64(0.12156862745098039),
#   np.float64(0.4666666666666667),
#   np.float64(0.7058823529411765),
#   np.float64(1.0)),
#  (np.float64(0.12156862745098039),
#   np.float64(0.4666666666666667),
#   np.float64(0.7058823529411765),
#   np.float64(1.0)),
#  (np.float64(1.0),
#   np.float64(0.4980392156862745),
#   np.float64(0.054901960784313725),
#   np.float64(1.0)),
#  (np.float64(0.17254901960784313),
#   np.float64(0.6274509803921569),
#   np.float64(0.17254901960784313),
#   np.float64(1.0)),
#  (np.float64(0.8392156862745098),
#   np.float64(0.15294117647058825),
#   np.float64(0.1568627450980392),
#   np.float64(1.0)),
#  (np.float64(0.8392156862745098),
#   np.float64(0.15294117647058825),
#   np.float64(0.1568627450980392),
#   np.float64(1.0)),
#  (np.float64(0.5803921568627451),
#   np.float64(0.403921568627451),
#   np.float64(0.7411764705882353),
#   np.float64(1.0)),
#  (np.float64(0.5490196078431373),
#   np.float64(0.33725490196078434),
# ...

# %% [markdown]
# ### Step 4: Draw Plot

# %%
plt.figure(figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')

for i, category in enumerate(categories):
    plt.scatter(
        "area",
        "poptotal",
        data=df.loc[df.category == category, :],
        s=20,
        c=[colours[i]],
        label=category
    )

plt.xlabel("Area")
plt.ylabel("Total Population")
plt.title("Midwest Area vs Population by Category")
plt.legend()
plt.show()

# %% [markdown]
# ## Scatter Plot With best Fit Line
#
# A best-fit line (regression line) shows the overall trend between two numerical variables.

# %% [markdown]
# ### Step 1: Initialize Global Setting

# %%
# Import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# setting up the params
large = 22
med = 12
small = 12

params = {
    'axes.titlesize': large,
    'legend.fontsize': med,
    'figure.figsize': (16, 10),
    'axes.labelsize': med,
    'xtick.labelsize': med,
    'ytick.labelsize': med,
    'figure.titlesize': large
}

# override default parameters of plot
plt.rcParams.update(params)

# set style (updated seaborn style)
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ### Step 2: Import Dataset

# %%
## "C:\Users\Prafull Wahatule\Desktop\Python_DA\Data\mpg.csv"


df = pd.read_csv(r"C:\Users\Prafull Wahatule\Desktop\Python_DA\Data\mpg.csv")
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %% [markdown]
# ### Step 3: Prepare Data

# %%
dfs = df.loc[df.cyl.isin([4,8])]
dfs
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 7           audi  a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p
# ..           ...         ...    ...   ...  ...         ...  ..  ...  ... ..
# 224   volkswagen  new beetle    2.0  1999    4    auto(l4)   f   19   26  r
# 227   volkswagen      passat    1.8  1999    4  manual(m5)   f   21   29  p
# 228   volkswagen      passat    1.8  1999    4    auto(l5)   f   18   29  p
# 229   volkswagen      passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen      passat    2.0  2008    4  manual(m6)   f   21   29  p
#
#           class
# 0       compact
# 1       compact
# ...

# %% [markdown]
# ### Step 4: Draw Plot

# %%
# Set seaborn background style to white for a clean look
sns.set_style("white")

# lmplot creates a scatter plot with a regression (best-fit) line
# It is a figure-level function based on FacetGrid
plotobj = sns.lmplot(
    x="displ",            # X-axis: engine displacement
    y="hwy",              # Y-axis: highway mileage
    hue="cyl",            # Group data by number of cylinders (color + line)
    data=dfs,             # Dataset used for plotting
    height=7,             # Height of the figure (in inches)
    aspect=1.6,           # Width = height × aspect
    robust=True,          # Uses robust regression (less sensitive to outliers)
    palette="tab10",      # Color palette for different cylinder groups
    scatter_kws=dict(     # Styling options for scatter points
        s=60,             # Size of each point
        linewidths=0.7,   # Border thickness of points
        edgecolors="black"  # Black outline for better visibility
    )
)

# Set X and Y axis limits
plotobj.set(xlim=(0.5, 7.5), ylim=(0, 50))

# Add a title to the entire figure (correct way for lmplot)
plotobj.fig.suptitle(
    "Scatter Plot with Line of Best Fit Grouped by Number of Cylinders",
    fontsize=large
)
# Out:
# Text(0.5, 0.98, 'Scatter Plot with Line of Best Fit Grouped by Number of Cylinders')

# %% [markdown]
# ## Correlation : Count Plot
#
# A count plot is NOT used to measure correlation in the statistical sense.
# Instead, it is used to compare frequencies between categories.

# %% [markdown]
# ### Step 1: Initialize Global Setting

# %%
# Import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# setting up the params
large = 22
med = 12
small = 12

params = {
    'axes.titlesize': large,
    'legend.fontsize': med,
    'figure.figsize': (16, 10),
    'axes.labelsize': med,
    'xtick.labelsize': med,
    'ytick.labelsize': med,
    'figure.titlesize': large
}

# override default parameters of plot
plt.rcParams.update(params)

# set style (updated seaborn style)
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ### Step 2: Import Dataset

# %%
## "C:\Users\Prafull Wahatule\Desktop\Python_DA\Data\mpg.csv"


df = pd.read_csv(r"C:\Users\Prafull Wahatule\Desktop\Python_DA\Data\mpg.csv")
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %% [markdown]
# ### Step 3: Prepare Data

# %%
df_counts = df.groupby(["hwy","cty"]).size().reset_index(name = "counts")
df_counts
# Out:
#     hwy  cty  counts
# 0    12    9       5
# 1    14   11       2
# 2    15   11      10
# 3    16   11       3
# 4    16   12       2
# ..  ...  ...     ...
# 73   36   25       1
# 74   37   28       1
# 75   41   29       1
# 76   44   33       1
# 77   44   35       1
#
# [78 rows x 3 columns]

# %% [markdown]
# ### Step 4: Draw Plot

# %%
fig, ax = plt.subplots(figsize=(16, 10), dpi=80)

ax.scatter(
    df_counts['cty'],
    df_counts['hwy'],
    s=df_counts['counts'] * 20,  # size represents frequency
    alpha=0.6
)

ax.set_xlabel("City Mileage")
ax.set_ylabel("Highway Mileage")
ax.set_title("Bubble Plot: Frequency of City vs Highway Mileage")
plt.show()

# %% [markdown]
# ## Correlation Distribution : Marginal Boxplot
#
# Marginal boxplots are used to visualize both the correlation between two numerical variables and the distribution of each variable along its axis.
#
# - Scatter: correlation/trend
#
# - Marginal box: spread, median, outliers

# %% [markdown]
# ### Step 1: Initialize Global Setting

# %% [markdown]
# ### Step 2: Import Dataset

# %% [markdown]
# ### Step 3: Prepare Data

# %% [markdown]
# ### Step 4: Draw Plot

# %% [markdown]
# ### Step 4: Draw Plot
