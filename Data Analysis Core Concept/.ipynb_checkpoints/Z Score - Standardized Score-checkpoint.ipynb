# %% [markdown]
# # Z Score - Standardized Score
#
# A Z-Score tells us how many standard deviations a value is away from the mean of the dataset.
# It converts data into a standard scale, so we can compare different values easily.
#
# Formula
# 𝑍 = 𝑋 − 𝜇 / 𝜎
#
# #### Where:
#
# X = individual value
#
# μ (mu) = mean
#
# σ (sigma) = standard deviation
#
# ### Interpretation of Z-Score
#  Z-Score    :	Meaning
#  0	        :   Value is exactly at the mean
#  +1	        :   1 SD above the mean
#  −1	        :   1 SD below the mean
#  +2	        :   2 SD above → unusually high
#  −2	        :   2 SD below → unusually low
#
#
# ### Why Z-Score is Important?
#
# 1. To detect outliers
#
# 2. To compare values from different scales
#
# 3. Used in standardization (machine learning)
#
# 4. Used in probability and statistics
#
#
# #### Example
#
# - Dataset mean (μ) = 50
# - Standard deviation (σ) = 10
# - Value (X) = 70
#
# 𝑍 = 70 − 50 / 10 = 2
#
# → Value is 2 standard deviations above the mean.
#
#
# *** Z-score tells how far a value is from the mean in units of standard deviation.
