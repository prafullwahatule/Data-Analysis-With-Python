# %% [markdown]
# # Central Tendency (Mean, Median, Mode)
#
# Central Tendency refers to statistical measures that describe the center point or typical value of a dataset.

# %% [markdown]
# ## Mean (Average)
# #### Definition:
#
# Mean is the sum of all values divided by the number of values.
#
# ### Formula:
# Mean = Sum of all values / Number of values
#
# #### Example:
#
# Values → 10, 20, 30
# Mean = (10 + 20 + 30) / 3 = 20

# %% [markdown]
# ## Median
# #### Definition:
#
# Median is the middle value of the dataset when numbers are arranged in ascending order.
#
# 1. For odd number of values:
#
# Median = middle value
#
# 2. For even number of values:
#
# Median = average of the two middle values
#
# ####  Example:
#
# Values → 10, 20, 30
# Median = 20
#
# Values → 10, 20, 30, 40
# Median = (20 + 30) / 2 = 25

# %% [markdown]
# ## Mode
# ### Definition:
#
# Mode is the value that occurs most frequently in the dataset.
#
# #### Example:
#
# Values → 2, 4, 4, 6, 7
# Mode = 4 (because 4 appears twice)
#
# 1. A dataset can have:
#
# One mode (unimodal)
#
# More than one mode (multimodal)
#
# No mode (if all values are unique)
