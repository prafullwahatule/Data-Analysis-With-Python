# %% [markdown]
# # DataFreame Basics

# %% [markdown]
# ### Check Shapes of DataFrame

# %%
import pandas as pd

# %%
wine = pd.read_csv(r"C:\Users\Prafull Wahatule\Desktop\Python_DA\Data\wine.csv")

# %%
print(wine)
# Out:
#     Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0      1    14.82        4.80  1.58  25.6  130     2.68        1.62
# 1      1    14.82        4.15  1.87  12.0   85     2.71        2.21
# 2      3    14.82        3.48  1.64  21.5  111     2.40        1.01
# 3      1    14.82        3.20  2.94  26.6  129     2.46        4.74
# 4      1    14.82        1.96  2.40  17.7  111     3.65        1.82
# ..   ...      ...         ...   ...   ...  ...      ...         ...
# 95     1    14.82        4.93  2.96  27.3  154     2.33        3.61
# 96     3    14.82        1.13  2.53  15.4  147     1.54        1.64
# 97     3    14.82        0.95  2.15  21.2  127     3.72        4.74
# 98     2    14.82        4.24  1.73  29.4  152     3.75        4.55
# 99     2    14.82        0.75  2.24  15.2  139     1.02        3.18
#
#     Nonflavanoid.phenols  Proanth
# 0                   0.13     3.04
# 1                   0.82     0.64
# 2                   0.38     0.87
# ...

# %%
wine.shape # This shape method tell you how many rows and coloumn are availbale in your data set
# Out:
# (100, 10)

# %% [markdown]
# ### Get Top 'n' Rows

# %%
wine.head(5) # this give you top 5 rows you can take it based on conditions like top 10, top 100  like this
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.82        4.80  1.58  25.6  130     2.68        1.62
# 1     1    14.82        4.15  1.87  12.0   85     2.71        2.21
# 2     3    14.82        3.48  1.64  21.5  111     2.40        1.01
# 3     1    14.82        3.20  2.94  26.6  129     2.46        4.74
# 4     1    14.82        1.96  2.40  17.7  111     3.65        1.82
#
#    Nonflavanoid.phenols  Proanth
# 0                  0.13     3.04
# 1                  0.82     0.64
# 2                  0.38     0.87
# 3                  0.90     3.89
# 4                  0.20     2.79

# %% [markdown]
# ### Get Last 'n' Rows

# %%
wine.tail(10) # this give you last records
# Out:
#     Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 90     2    14.82        3.99  1.97  29.2   86     2.71        1.69
# 91     1    14.82        3.84  3.48  18.6   85     3.35        4.38
# 92     3    14.82        2.19  2.45  29.3   74     2.33        2.85
# 93     1    14.82        4.08  2.66  19.0  146     3.21        2.24
# 94     1    14.82        4.73  1.72  11.2   94     1.88        2.45
# 95     1    14.82        4.93  2.96  27.3  154     2.33        3.61
# 96     3    14.82        1.13  2.53  15.4  147     1.54        1.64
# 97     3    14.82        0.95  2.15  21.2  127     3.72        4.74
# 98     2    14.82        4.24  1.73  29.4  152     3.75        4.55
# 99     2    14.82        0.75  2.24  15.2  139     1.02        3.18
#
#     Nonflavanoid.phenols  Proanth
# 90                  0.12     3.29
# 91                  0.39     0.94
# 92                  0.46     0.63
# 93                  0.54     1.60
# 94                  0.20     0.66
# ...

# %% [markdown]
# ### Get Range of Entries

# %%
 wine[50:60] # this give you a range result like if you want to rows between row No: 10 to row no:15 this give
# Out:
#     Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 50     1    14.82        3.97  3.04  27.6  100     1.10        3.68
# 51     1    14.82        2.87  1.92  14.4  153     1.64        3.67
# 52     2    14.82        4.57  2.76  17.7  125     3.37        3.11
# 53     3    14.82        2.51  2.95  29.0  130     2.62        0.53
# 54     1    14.82        1.60  1.57  10.7  116     1.93        2.03
# 55     2    14.82        3.65  2.64  17.5  129     3.85        4.84
# 56     3    14.82        4.81  2.04  12.5  106     1.24        1.58
# 57     2    14.82        2.73  1.74  27.5  120     1.58        2.91
# 58     2    14.82        2.11  1.57  18.7  126     3.50        0.97
# 59     2    14.82        3.26  2.70  22.3  143     2.19        4.14
#
#     Nonflavanoid.phenols  Proanth
# 50                  0.23     1.65
# 51                  0.75     0.91
# 52                  0.31     3.79
# 53                  0.67     1.07
# 54                  0.68     2.32
# ...

# %% [markdown]
# ### Accessing DataFram Columns

# %%
wine.columns    # this give you all column list
# Out:
# Index(['Wine', 'Alcohol', 'Malic.acid', 'Ash', 'Acl', 'Mg', 'Phenols',
#        'Flavanoids', 'Nonflavanoid.phenols', 'Proanth'],
#       dtype='object')

# %% [markdown]
# ### Accessing 'n' Column

# %%
wine['Wine'] # this give you  only one column in return
# Out:
# 0     1
# 1     1
# 2     3
# 3     1
# 4     1
#      ..
# 95    1
# 96    3
# 97    3
# 98    2
# 99    2
# Name: Wine, Length: 100, dtype: int64

# %%
wine[['Wine','Alcohol','Mg','Phenols']]  # Accessing multiple columns
# Out:
#     Wine  Alcohol   Mg  Phenols
# 0      1    14.82  130     2.68
# 1      1    14.82   85     2.71
# 2      3    14.82  111     2.40
# 3      1    14.82  129     2.46
# 4      1    14.82  111     3.65
# ..   ...      ...  ...      ...
# 95     1    14.82  154     2.33
# 96     3    14.82  147     1.54
# 97     3    14.82  127     3.72
# 98     2    14.82  152     3.75
# 99     2    14.82  139     1.02
#
# [100 rows x 4 columns]

# %% [markdown]
# ### Checking Column Type

# %%
type(wine['Wine'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Common Operations on Columns

# %%
wine['Mg'].std() # Standard Deviation
# Out:
# 25.583683247039477

# %%
wine[wine.Mg == wine['Mg'].min()] # Return minimum MG with all columns detials
# Out:
#     Wine  Alcohol  Malic.acid   Ash   Acl  Mg  Phenols  Flavanoids  \
# 9      1    14.82        1.72  2.43  15.2  70      2.8        4.83
# 10     2    14.82        1.95  2.58  15.5  70      2.9        4.18
#
#     Nonflavanoid.phenols  Proanth
# 9                   0.61     2.23
# 10                  0.74     0.65

# %% [markdown]
# ### The Describe Method

# %%
wine['Malic.acid'].describe()  # This give you all details about given column
# Out:
# count    100.00000
# mean       3.06460
# std        1.27683
# min        0.72000
# 25%        1.95750
# 50%        3.27000
# 75%        4.17000
# max        5.00000
# Name: Malic.acid, dtype: float64

# %% [markdown]
# ### Conditional Operation on Column

# %%
wine[wine.Ash >= 3]
# Out:
#     Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 6      2    14.82        4.41  3.19  18.0  137     3.58        4.93
# 7      2    14.82        0.72  3.44  17.9   71     1.84        0.62
# 12     3    14.82        3.23  3.12  14.1  111     3.66        1.10
# 13     1    14.82        4.53  3.06  16.2  114     1.39        3.26
# 14     1    14.82        5.00  3.15  14.9  154     3.31        0.74
# 20     1    14.82        4.40  3.23  11.5  159     1.45        2.22
# 31     2    14.82        1.47  3.23  14.4   73     3.56        3.95
# 33     1    14.82        2.72  3.40  14.5  118     1.41        2.38
# 37     2    14.82        1.37  3.30  20.2  124     3.76        1.65
# 39     1    14.82        4.08  3.25  25.6  152     3.26        4.25
# 40     3    14.82        2.56  3.03  23.0  125     2.88        3.71
# 48     2    14.82        3.15  3.33  18.8  126     1.51        3.51
# 50     1    14.82        3.97  3.04  27.6  100     1.10        3.68
# ...

# %% [markdown]
# ### Set Index

# %%
all_fruits = pd.read_csv(r"C:\Users\Prafull Wahatule\Desktop\Python_DA\Data\all_fruits.csv")

# %%
print(all_fruits)
# Out:
#            Fruits  Price InStock
# 0           Apple    626      No
# 1          Orange    481      No
# 2          Banana   1014     Yes
# 3          Grapes    144      No
# 4           Mango    922     Yes
# ..            ...    ...     ...
# 97   Prickly Pear    603     Yes
# 98      Carambola    246     Yes
# 99        Kumquat    279      No
# 100        Loquat    294     Yes
# 101     Cherimoya    169     Yes
#
# [102 rows x 3 columns]

# %%
all_fruits.set_index('Fruits', inplace = True)

# %% [markdown]
# ### Ioc And iloc

# %%
all_fruits.loc['Apple']
# Out:
# Price      626
# InStock     No
# Name: Apple, dtype: object

# %%
all_fruits.iloc[0]
# Out:
# Price      626
# InStock     No
# Name: Apple, dtype: object
