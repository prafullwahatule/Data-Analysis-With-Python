# %% [markdown]
# # Seaborn Plot Overview

# %% [markdown]
# ### 1. What is Seaborn?
# ### 2. Why to use Seaborn?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rng = np.random.RandomState(0)
x = np.linspace(0,10,500)
y = np.cumsum(rng.randn(500,6),0)

# %%
plt.plot(x,y)
plt.legend("ABCDEF", ncol =2, loc ="upper left")

# %% [markdown]
# #### Now we use Seaborn And get above graph above we use matplotlib

# %%
sns.set()

# %%
plt.plot(x,y)
plt.legend("ABCDEF", ncol =2, loc ="upper left")

# %%
d = np.random.multivariate_normal([0,0],[[5,2],[2,2]], size = 2000)
df = pd.DataFrame(d,columns = ["x","y"])

# %%
df
# Out:
#              x         y
# 0    -0.223851  0.983974
# 1    -1.090789 -2.253284
# 2     2.104225  0.218248
# 3    -1.306418 -1.452466
# 4     1.555058  0.971447
# ...        ...       ...
# 1995 -0.726959  0.892433
# 1996 -3.323084 -1.164617
# 1997  3.311784  1.595291
# 1998 -4.206446 -0.420402
# 1999 -3.346912 -1.390185
#
# [2000 rows x 2 columns]

# %%
sns.histplot(df["x"], kde=True)
sns.histplot(df["y"], kde=True)
# Out:
# <Axes: xlabel='x', ylabel='Count'>
